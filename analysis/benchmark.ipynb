# %%
import pandas as pd

# %%
benchmark_df = pd.read_csv('benchmark-results-c-testsuite-gcc-11-vs-gcc-12.csv')

# %%
benchmark_df
# Out:
#     threads  num_mutants int_bounds  num_seeds  total_attempts  \
# 0         1           32      int8+        152            4864
# 1         1           32      int8+        152            4864
# 2         2           32      int8+        152            4864
# 3         2           32      int8+        152            4864
# 4         2           32      int8+        152            4864
# 5         4           32      int8+        152            4864
# 6         4           32      int8+        152            4864
# 7         4           32      int8+        152            4865
# 8         8           32      int8+        152            4871
# 9         8           32      int8+        152            4873
# 10        8           32      int8+        152            4874
# 11       16           32      int8+        152            4890
# 12       16           32      int8+        152            4895
# 13       16           32      int8+        152            4900
# ...
