# %%
import pandas as pd
# Out:
# hello world

# %%
results_all = pd.read_csv('../results/jonas/fuzz-all-0/mutation_attempts.csv')

# %%
results_all.head()
# Out:
#         filename  mutation-id  checker-success checker-info  checker-stdout  \
# 0  00001.c.clean            0             True        valid             NaN
# 1  00001.c.clean            1             True        valid             NaN
# 2  00001.c.clean            2             True        valid             NaN
# 3  00001.c.clean            3             True        valid             NaN
# 4  00001.c.clean            4             True        valid             NaN
#
#   checker-stderr  asm_diff    c-0  c-1  c-2  ...  c-1593  c-1594  c-1595  \
# 0            NaN       0.0   15.0  NaN  NaN  ...     NaN     NaN     NaN
# 1            NaN       0.0   96.0  NaN  NaN  ...     NaN     NaN     NaN
# 2            NaN       0.0  104.0  NaN  NaN  ...     NaN     NaN     NaN
# 3            NaN       0.0   80.0  NaN  NaN  ...     NaN     NaN     NaN
# 4            NaN       0.0   96.0  NaN  NaN  ...     NaN     NaN     NaN
#
#    c-1596  c-1597  c-1598  c-1599  c-1600  c-1601  c-1602
# 0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# [5 rows x 1610 columns]

# %%
results_diffs = results_all[results_all['asm_diff'] > 0]

# %%
results_per_seed = results_diffs.groupby('filename').count()
results_per_seed
# Out:
#                       mutation-id  checker-success  checker-info  \
# filename
# 00009.c.clean                   1                1             1
# 00024.c.clean                  20               20            20
# 00140.c.clean                  20               20            20
# 20001203-1.c.clean              4                4             4
# 20010910-1.c.clean              6                6             6
# 20011019-1.c.clean             23               23            23
# 20020118-1.c.clean             16               16            16
# 20020201-1.c.clean              1                1             1
# 20030221-1.c.clean              1                1             1
# 20051110-2.c.clean              2                2             2
# 20081103-1.c.clean              1                1             1
# 20100416-1.c.clean             19               19            19
# 20140326-1.c.clean              1                1             1
# pr21173.c.clean                 4                4             4
# pr34070-1.c.clean               2                2             2
# pr42248.c.clean                20               20            20
# pr47337.c.clean                 6                6             6
# pr56250.c.clean                 5                5             5
# pr58662.c.clean                 1                1             1
# pr68911.c.clean                 6                6             6
# pr71631.c.clean                 1                1             1
# pr78477.c.clean                 2                2             2
# pr78856.c.clean                14               14            14
# pr94809.c.clean                20               20            20
# pr97836.c.clean                18               18            18
# string-opt-5.c.clean           21               21            21
#
#                       checker-stdout  checker-stderr  asm_diff  c-0  c-1  c-2  \
# filename
# 00009.c.clean                      0               0         1    1    1    1
# 00024.c.clean                      0               0        20   20   20   20
# 00140.c.clean                      0               0        20   20   20   20
# 20001203-1.c.clean                 0               0         4    4    4    4
# 20010910-1.c.clean                 0               0         6    6    6    6
# 20011019-1.c.clean                 0               0        23   23   23    0
# 20020118-1.c.clean                 0               0        16   16   16   16
# 20020201-1.c.clean                 0               0         1    1    1    1
# 20030221-1.c.clean                 0               0         1    1    1    1
# 20051110-2.c.clean                 0               0         2    2    2    2
# 20081103-1.c.clean                 0               0         1    1    1    1
# 20100416-1.c.clean                 0               0        19   19   19   19
# 20140326-1.c.clean                 0               0         1    1    1    1
# pr21173.c.clean                    0               0         4    4    4    4
# pr34070-1.c.clean                  0               0         2    2    2    2
# pr42248.c.clean                    0               0        20   20   20   20
# pr47337.c.clean                    0               0         6    6    6    6
# pr56250.c.clean                    0               0         5    5    5    5
# pr58662.c.clean                    0               0         1    1    1    1
# pr68911.c.clean                    0               0         6    6    6    6
# pr71631.c.clean                    0               0         1    1    1    1
# pr78477.c.clean                    0               0         2    2    2    2
# pr78856.c.clean                    0               0        14   14   14   14
# pr94809.c.clean                    0               0        20   20   20   20
# pr97836.c.clean                    0               0        18   18   18    0
# string-opt-5.c.clean               0               0        21   21   21   21
#
#                       c-3  ...  c-1593  c-1594  c-1595  c-1596  c-1597  \
# filename                   ...
# 00009.c.clean           1  ...       0       0       0       0       0
# 00024.c.clean           0  ...       0       0       0       0       0
# 00140.c.clean          20  ...       0       0       0       0       0
# 20001203-1.c.clean      4  ...       0       0       0       0       0
# 20010910-1.c.clean      6  ...       0       0       0       0       0
# 20011019-1.c.clean      0  ...       0       0       0       0       0
# 20020118-1.c.clean     16  ...       0       0       0       0       0
# 20020201-1.c.clean      1  ...       0       0       0       0       0
# 20030221-1.c.clean      1  ...       0       0       0       0       0
# 20051110-2.c.clean      2  ...       0       0       0       0       0
# 20081103-1.c.clean      1  ...       0       0       0       0       0
# 20100416-1.c.clean     19  ...       0       0       0       0       0
# 20140326-1.c.clean      1  ...       0       0       0       0       0
# pr21173.c.clean         4  ...       0       0       0       0       0
# pr34070-1.c.clean       2  ...       0       0       0       0       0
# pr42248.c.clean         0  ...       0       0       0       0       0
# pr47337.c.clean         6  ...       0       0       0       0       0
# pr56250.c.clean         5  ...       0       0       0       0       0
# pr58662.c.clean         1  ...       0       0       0       0       0
# pr68911.c.clean         6  ...       0       0       0       0       0
# pr71631.c.clean         1  ...       0       0       0       0       0
# pr78477.c.clean         2  ...       0       0       0       0       0
# pr78856.c.clean        14  ...       0       0       0       0       0
# pr94809.c.clean        20  ...       0       0       0       0       0
# pr97836.c.clean         0  ...       0       0       0       0       0
# string-opt-5.c.clean   21  ...       0       0       0       0       0
#
#                       c-1598  c-1599  c-1600  c-1601  c-1602
# filename
# 00009.c.clean              0       0       0       0       0
# 00024.c.clean              0       0       0       0       0
# 00140.c.clean              0       0       0       0       0
# 20001203-1.c.clean         0       0       0       0       0
# 20010910-1.c.clean         0       0       0       0       0
# 20011019-1.c.clean         0       0       0       0       0
# 20020118-1.c.clean         0       0       0       0       0
# 20020201-1.c.clean         0       0       0       0       0
# 20030221-1.c.clean         0       0       0       0       0
# 20051110-2.c.clean         0       0       0       0       0
# 20081103-1.c.clean         0       0       0       0       0
# 20100416-1.c.clean         0       0       0       0       0
# 20140326-1.c.clean         0       0       0       0       0
# pr21173.c.clean            0       0       0       0       0
# pr34070-1.c.clean          0       0       0       0       0
# pr42248.c.clean            0       0       0       0       0
# pr47337.c.clean            0       0       0       0       0
# pr56250.c.clean            0       0       0       0       0
# pr58662.c.clean            0       0       0       0       0
# pr68911.c.clean            0       0       0       0       0
# pr71631.c.clean            0       0       0       0       0
# pr78477.c.clean            0       0       0       0       0
# pr78856.c.clean            0       0       0       0       0
# pr94809.c.clean            0       0       0       0       0
# pr97836.c.clean            0       0       0       0       0
# string-opt-5.c.clean       0       0       0       0       0
#
# [26 rows x 1609 columns]

# %%
max_results_per_seed = results_diffs.groupby('filename').max('asm_diff')
max_results_per_seed
# Out:
#                       mutation-id  checker-success  checker-stdout  asm_diff  \
# filename
# 00009.c.clean                  22             True             NaN       1.0
# 00024.c.clean                  19             True             NaN       1.0
# 00140.c.clean                  19             True             NaN      16.0
# 20001203-1.c.clean             15             True             NaN       1.0
# 20010910-1.c.clean             20             True             NaN       1.0
# 20011019-1.c.clean             22             True             NaN       1.0
# 20020118-1.c.clean             19             True             NaN       1.0
# 20020201-1.c.clean              4             True             NaN       1.0
# 20030221-1.c.clean              1             True             NaN       1.0
# 20051110-2.c.clean             19             True             NaN       1.0
# 20081103-1.c.clean              4             True             NaN       9.0
# 20100416-1.c.clean             18             True             NaN       1.0
# 20140326-1.c.clean              8             True             NaN       1.0
# pr21173.c.clean                17             True             NaN       1.0
# pr34070-1.c.clean               7             True             NaN       2.0
# pr42248.c.clean                19             True             NaN       6.0
# pr47337.c.clean                18             True             NaN       1.0
# pr56250.c.clean                21             True             NaN       1.0
# pr58662.c.clean                17             True             NaN       2.0
# pr68911.c.clean                16             True             NaN       1.0
# pr71631.c.clean                11             True             NaN       4.0
# pr78477.c.clean                 2             True             NaN       1.0
# pr78856.c.clean                19             True             NaN       1.0
# pr94809.c.clean                19             True             NaN       1.0
# pr97836.c.clean                17             True             NaN       1.0
# string-opt-5.c.clean           21             True             NaN       1.0
#
#                         c-0    c-1    c-2    c-3    c-4    c-5  ...  c-1593  \
# filename                                                        ...
# 00009.c.clean          82.0   78.0   28.0    2.0   39.0    NaN  ...     NaN
# 00024.c.clean         122.0  125.0  124.0    NaN    NaN    NaN  ...     NaN
# 00140.c.clean         119.0  121.0  115.0  125.0  123.0  125.0  ...     NaN
# 20001203-1.c.clean    108.0   79.0   99.0  124.0  115.0    NaN  ...     NaN
# 20010910-1.c.clean    104.0  115.0  117.0  117.0  111.0  112.0  ...     NaN
# 20011019-1.c.clean    126.0  120.0    NaN    NaN    NaN    NaN  ...     NaN
# 20020118-1.c.clean    121.0  125.0  126.0  124.0  123.0  127.0  ...     NaN
# 20020201-1.c.clean     50.0   62.0   21.0  115.0   97.0   59.0  ...     NaN
# 20030221-1.c.clean     26.0   11.0   86.0  121.0   30.0    NaN  ...     NaN
# 20051110-2.c.clean     79.0  109.0   45.0   60.0   79.0   43.0  ...     NaN
# 20081103-1.c.clean     33.0   79.0   28.0   24.0  118.0    NaN  ...     NaN
# 20100416-1.c.clean    126.0  123.0  127.0  125.0  114.0  118.0  ...     NaN
# 20140326-1.c.clean     92.0   30.0   29.0   69.0   96.0    NaN  ...     NaN
# pr21173.c.clean       107.0   60.0  110.0   44.0  101.0    NaN  ...     NaN
# pr34070-1.c.clean      64.0   62.0  100.0   87.0    NaN    NaN  ...     NaN
# pr42248.c.clean       116.0  122.0  123.0    NaN    NaN    NaN  ...     NaN
# pr47337.c.clean       115.0  124.0  116.0  126.0  101.0   86.0  ...     NaN
# pr56250.c.clean       104.0  126.0  117.0   89.0    NaN    NaN  ...     NaN
# pr58662.c.clean        89.0   29.0   35.0   64.0   20.0   70.0  ...     NaN
# pr68911.c.clean       122.0  125.0  125.0  127.0  125.0   76.0  ...     NaN
# pr71631.c.clean        83.0   17.0   20.0   96.0    3.0    1.0  ...     NaN
# pr78477.c.clean        24.0   83.0   25.0   17.0  111.0  126.0  ...     NaN
# pr78856.c.clean       125.0  111.0  123.0  127.0  125.0  102.0  ...     NaN
# pr94809.c.clean       117.0  127.0  124.0  127.0    NaN    NaN  ...     NaN
# pr97836.c.clean       104.0  124.0    NaN    NaN    NaN    NaN  ...     NaN
# string-opt-5.c.clean  123.0  127.0  113.0  125.0   85.0  126.0  ...     NaN
#
#                       c-1594  c-1595  c-1596  c-1597  c-1598  c-1599  c-1600  \
# filename
# 00009.c.clean            NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 00024.c.clean            NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 00140.c.clean            NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 20001203-1.c.clean       NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 20010910-1.c.clean       NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 20011019-1.c.clean       NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 20020118-1.c.clean       NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 20020201-1.c.clean       NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 20030221-1.c.clean       NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 20051110-2.c.clean       NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 20081103-1.c.clean       NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 20100416-1.c.clean       NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 20140326-1.c.clean       NaN     NaN     NaN     NaN     NaN     NaN     NaN
# pr21173.c.clean          NaN     NaN     NaN     NaN     NaN     NaN     NaN
# pr34070-1.c.clean        NaN     NaN     NaN     NaN     NaN     NaN     NaN
# pr42248.c.clean          NaN     NaN     NaN     NaN     NaN     NaN     NaN
# pr47337.c.clean          NaN     NaN     NaN     NaN     NaN     NaN     NaN
# pr56250.c.clean          NaN     NaN     NaN     NaN     NaN     NaN     NaN
# pr58662.c.clean          NaN     NaN     NaN     NaN     NaN     NaN     NaN
# pr68911.c.clean          NaN     NaN     NaN     NaN     NaN     NaN     NaN
# pr71631.c.clean          NaN     NaN     NaN     NaN     NaN     NaN     NaN
# pr78477.c.clean          NaN     NaN     NaN     NaN     NaN     NaN     NaN
# pr78856.c.clean          NaN     NaN     NaN     NaN     NaN     NaN     NaN
# pr94809.c.clean          NaN     NaN     NaN     NaN     NaN     NaN     NaN
# pr97836.c.clean          NaN     NaN     NaN     NaN     NaN     NaN     NaN
# string-opt-5.c.clean     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#                       c-1601  c-1602
# filename
# 00009.c.clean            NaN     NaN
# 00024.c.clean            NaN     NaN
# 00140.c.clean            NaN     NaN
# 20001203-1.c.clean       NaN     NaN
# 20010910-1.c.clean       NaN     NaN
# 20011019-1.c.clean       NaN     NaN
# 20020118-1.c.clean       NaN     NaN
# 20020201-1.c.clean       NaN     NaN
# 20030221-1.c.clean       NaN     NaN
# 20051110-2.c.clean       NaN     NaN
# 20081103-1.c.clean       NaN     NaN
# 20100416-1.c.clean       NaN     NaN
# 20140326-1.c.clean       NaN     NaN
# pr21173.c.clean          NaN     NaN
# pr34070-1.c.clean        NaN     NaN
# pr42248.c.clean          NaN     NaN
# pr47337.c.clean          NaN     NaN
# pr56250.c.clean          NaN     NaN
# pr58662.c.clean          NaN     NaN
# pr68911.c.clean          NaN     NaN
# pr71631.c.clean          NaN     NaN
# pr78477.c.clean          NaN     NaN
# pr78856.c.clean          NaN     NaN
# pr94809.c.clean          NaN     NaN
# pr97836.c.clean          NaN     NaN
# string-opt-5.c.clean     NaN     NaN
#
# [26 rows x 1607 columns]

# %%
max_results_overview = max_results_per_seed[['mutation-id', 'asm_diff']]
max_results_overview
# Out:
#                       mutation-id  asm_diff
# filename
# 00009.c.clean                  22       1.0
# 00024.c.clean                  19       1.0
# 00140.c.clean                  19      16.0
# 20001203-1.c.clean             15       1.0
# 20010910-1.c.clean             20       1.0
# 20011019-1.c.clean             22       1.0
# 20020118-1.c.clean             19       1.0
# 20020201-1.c.clean              4       1.0
# 20030221-1.c.clean              1       1.0
# 20051110-2.c.clean             19       1.0
# 20081103-1.c.clean              4       9.0
# 20100416-1.c.clean             18       1.0
# 20140326-1.c.clean              8       1.0
# pr21173.c.clean                17       1.0
# pr34070-1.c.clean               7       2.0
# pr42248.c.clean                19       6.0
# pr47337.c.clean                18       1.0
# pr56250.c.clean                21       1.0
# pr58662.c.clean                17       2.0
# pr68911.c.clean                16       1.0
# pr71631.c.clean                11       4.0
# pr78477.c.clean                 2       1.0
# pr78856.c.clean                19       1.0
# pr94809.c.clean                19       1.0
# pr97836.c.clean                17       1.0
# string-opt-5.c.clean           21       1.0

# %%
max_results_overview.to_csv('../results/jonas/fuzz-all-max-diffs-with-unique-seed/info.csv')

# %%
max_results_overview[max_results_overview['asm_diff'] > 1]
# Out:
#                     mutation-id  asm_diff
# filename
# 00140.c.clean                19      16.0
# 20081103-1.c.clean            4       9.0
# pr34070-1.c.clean             7       2.0
# pr42248.c.clean              19       6.0
# pr58662.c.clean              17       2.0
# pr71631.c.clean              11       4.0
